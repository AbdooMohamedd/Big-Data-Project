# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
file_path = r"C:\Users\dell\Desktop\Full cleand fifa players 2.csv"  # Replace with your dataset file path

# %%
# Preparing the target variable and features
target_variable_lr = 'Skill Moves'
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(df[target_variable_lr])
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
selected_features_lr = [feature for feature in numerical_features if feature not in ['Player ID']]
X = df[selected_features_lr]

# %%
# Splitting the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Standardizing the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Logistic Regression model
lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train_scaled, y_train)
y_pred_lr = lr_model.predict(X_test_scaled)

# %%
# Accuracy
accuracy_lr = accuracy_score(y_test, y_pred_lr)

# %%
# Confusion matrix
cm_lr = confusion_matrix(y_test, y_pred_lr)

# %%
accuracy_percentage = accuracy_lr * 100
print("Accuracy in percentage:", accuracy_percentage)
# Out:
# Accuracy in percentage: 99.92690058479532

# %%
# Plotting the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm_lr, annot=True, fmt='g', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title('Confusion Matrix for Logistic Regression Classifier')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
